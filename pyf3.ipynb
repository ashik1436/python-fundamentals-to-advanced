# %% [markdown]
# <a href="https://colab.research.google.com/github/ashik1436/python-fundamentals-to-advanced/blob/main/pyf3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s=input("enter a string:")
if s==s[::-1]:
  print("palindrom")
else:
  print("not palindrom")
# Out:
# enter a string:madam
# palindrom

# %%
nums = list(map(int, input("Enter numbers separated by space: ").split()))
total = sum(nums)
count = len(nums)
avg = total / count
print("Average:", avg)
# Out:
# Enter numbers separated by space: 1 2 1 2
# Average: 1.5

# %%
list1=list(map(int,input().split()))
list2=list(map(int,input().split()))
both=list1+list2
both.sort()
print(both)
# Out:
# 1 2 3 4 21 1
# 1 2 3 2 1 56 32
# [1, 1, 1, 1, 2, 2, 2, 3, 3, 4, 21, 32, 56]

# %%
t=tuple(map(int,input().split()))
even=tuple(x for x in t if x%2==0)
odd=tuple(x for x in t if x%2!=0)
print("even numbers are:",even)
print("odd numbers are:",odd)
# Out:
# 1 2 3 2 1 233 111 222
# even numbers are: (2, 2, 222)
# odd numbers are: (1, 3, 1, 233, 111)

# %%
d={}
while True:
  print("\nA: Add student\nB: Update marks\nC: Search student\nD: Display all\nQ: Quit")
  choice=input("Enter your choice: ").upper()
  if choice=="A":
    name=input("Enter student name: ")
    marks=int(input("Enter student marks: "))
    d[name]=marks
  elif choice=="B":
    name=input("Enter student name: ")
    if name in d:
      marks=int(input("Enter new marks: "))
      d[name]=marks
    else:
      print("Student not found")
  elif choice=="C":
    name=input("Enter student name: ")
    if name in d:
      print(f"{name}: {d[name]}")
    else:
      print("Student not found")
  elif choice=="D":
    for name,marks in d.items():
      print(f"{name}: {marks}")
  elif choice=="Q":
    break
  else:
    print("Invalid choice")
# Out:
# A: Add student
# B: Update marks
# C: Search student
# D: Display all
# Q: Quit
# Enter your choice: a
# Enter student name: ashik
# Enter student marks: 99
#
# A: Add student
# B: Update marks
# C: Search student
# D: Display all
# Q: Quit
# Enter your choice: d
# ashik: 99
#
# A: Add student
# B: Update marks
# C: Search student
# D: Display all
# Q: Quit
# Enter your choice: a
# Enter student name: ishuu
# Enter student marks: 100
#
# A: Add student
# B: Update marks
# C: Search student
# D: Display all
# Q: Quit
# Enter your choice: d
# ashik: 99
# ishuu: 100
#
# A: Add student
# B: Update marks
# C: Search student
# D: Display all
# Q: Quit
# Enter your choice: q

# %%
words=["apple","banana","kiwi"]
word_lenth={word:len(word)for word in words}
print(word_lenth)
# Out:
# {'apple': 5, 'banana': 6, 'kiwi': 4}

# %%
text = input("Enter a string: ")

spaces = text.count(" ")
print("Number of spaces:", spaces)
# Out:
# Enter a string:
# Number of spaces: 4

# %%
list1 = list(map(int, input("Enter list1: ").split()))
list2 = list(map(int, input("Enter list2: ").split()))

if set(list1).isdisjoint(set(list2)):
    print("No common elements")
else:
    print("Common elements exist")
# Out:
# Enter list1: 1 2 3 1
# Enter list2: 1 2 3 4 2 1
# Common elements exist

# %%
nums = list(map(int, input("Enter list: ").split()))

duplicates = set([x for x in nums if nums.count(x) > 1])

print("Duplicate elements:", duplicates)
# Out:
# Enter list: 1 2 3 2 1 3 11 1
# Duplicate elements: {1, 2, 3}
